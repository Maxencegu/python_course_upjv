# %% [markdown]
# # **1. Les bases de Python**

# %% [markdown]
# ## **1.1 Bonjour Python !**

# %% [markdown]
# Vous allez découvrir comment Python peut vous aider à manipuler et analyser des données, une compétence essentielle pour tout professionnel en science des données.

# %% [markdown]
# ### **Votre premier code Python**
#
# Il est temps d'exécuter votre premier code Python.
#
# La fonction `print(...) ` permet d'afficher à l'écran le résultat de l'instruction passée entre les pararenthèses.

# %% [markdown]
# **Instructions**
#
# `Appuyez sur le bouton d'exécution du code pour voir la sortie de print(5 / 8)`

# %%
print(5 / 8)

# %% [markdown]
# ### **Python comme calculatrice**
#
# Python est parfaitement adapté pour effectuer des calculs de base. Il peut effectuer des additions, des soustractions, des multiplications et des divisions.
#
# Le code dans ce script donne quelques exemples.
#
# À présent, c'est à vous de vous exercer en écrivant vous-même du code.

# %% [markdown]
# **Instructions**
#
# 1. Affichez le résultat de la soustraction de 5 par 5 sous `# Subtraction` en utilisant `print()`.
# 2. Affichez le résultat de la multiplication de 3 par 5 sous `# Multiplication` en utilisant `print()`.

# %%
# Addition and division
print(4 + 5)
print(10 / 2)

# Subtraction
____

# Multiplication
____

# %% [markdown]
# ## **1.2 Variables et types**

# %% [markdown]
# Cette leçon vous aidera à comprendre comment créer et utiliser des variables en Python, une compétence essentielle pour rendre votre code plus flexible et reproductible dans vos analyses.

# %%
# @title
from IPython.display import HTML

pdf_url_01 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/01_python_variables_and_types.pdf"

HTML(f"""
<a href="{pdf_url_01}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/01_python_variables_and_types.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_01 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_01.png"

# Affiche l'image
Image(url=image_url_01, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_01.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Affectation de variable**
#
# En Python, une variable permet de faire référence à une valeur à l’aide d’un nom. Pour créer une variable `x` avec la valeur `5`, vous utilisez `=` comme dans l’exemple suivant :
#
# ```python
# x = 5
# ```
#
# Vous pouvez maintenant utiliser le nom de cette variable, `x`, au lieu de la valeur réelle, `5`.
#
# Rappelez-vous : en Python, `=` signifie une affectation, cela ne sert pas à tester l’égalité !
#
# ---
#
#
# ### **Instructions**
#
# 1. Créez une variable `savings` avec la valeur `100`.
# 2. Vérifiez cette variable en tapant `print(savings)` dans le script.

# %%
# Create a variable savings
____

# Print out savings
____

# %% [markdown]
# ### **Exercice**
# **Calculs avec des variables**
#
# Vous avez maintenant créé une variable `savings`, alors commençons à épargner !
#
# Au lieu de faire des calculs avec des valeurs directement, vous pouvez utiliser des variables.
#
# Combien d’argent aurez-vous économisé dans quatre mois si vous épargnez 10 $ chaque mois ?
#
# ---
#
# ### **Instructions**
#
# 1. Créez une variable `monthly_savings`, égale à `10`, et une variable `num_months`, égale à `4`.
# 2. Multipliez `monthly_savings` par `num_months` et affectez le résultat à `new_savings`.
# 3. Affichez la valeur de `new_savings`.

# %%
# Create the variables monthly_savings and num_months
____
____

# Multiply monthly_savings and num_months
new_savings = ____

# Print new_savings
____

# %% [markdown]
# ### **Exercice**
# **Autres types de variables**
#
# Dans l’exercice précédent, vous avez travaillé avec le type de données Python **entier** :
#
# - `int` (integer) : un nombre sans partie décimale.
#   `savings`, avec la valeur `100`, est un exemple d’entier.
#
# En plus des types numériques, il existe trois autres types de données très courants :
#
# - `float` (nombre à virgule flottante) : un nombre qui possède une partie entière et une partie décimale, séparées par un point.
#   `1.1` est un exemple de `float`.
#
# - `str` (string / chaîne de caractères) : un type utilisé pour représenter du texte.
#   Vous pouvez utiliser des guillemets simples `' '` ou doubles `" "` pour créer une chaîne.
#
# - `bool` (boolean / booléen) : un type utilisé pour représenter des valeurs logiques.
#   Il ne peut prendre que deux valeurs : `True` ou `False` (la majuscule est importante !).
#
# ---
#
# ### **Instructions**
#
# 1. Créez un nouveau **float** `half` avec la valeur `0.5`.
# 2. Créez une nouvelle **chaîne de caractères** `intro` avec la valeur `"Hello! How are you?"`.
# 3. Créez un nouveau **booléen** `is_good` avec la valeur `True`.

# %%
# Create a variable half
____

# Create a variable intro
____

# Create a variable is_good
____

# %% [markdown]
# ### **Exercice**
# **Opérations avec d’autres types**
#
# Les variables existent sous différents types en Python.
# Vous pouvez connaître le type d’une variable en utilisant `type()`.
# Par exemple, pour connaître le type de `a`, exécutez : `type(a)`.
#
# Les différents types se comportent différemment en Python.
# Lorsque vous additionnez deux chaînes de caractères, par exemple, vous obtiendrez un comportement différent de celui obtenu en additionnant deux entiers ou deux booléens.
#
# À vous de tester cela maintenant !
#
# ---
#
# ### **Instructions 1 / 2**
#
# 1. Additionnez `savings` et `new_savings`, puis affectez le résultat à `total_savings`.
# 2. Utilisez `type()` pour afficher le type obtenu pour `total_savings`.

# %%
savings = 100
new_savings = 40

# Calculate total_savings using savings and new_savings
____
print(____)

# Print the type of total_savings
print(____)

# %% [markdown]
# ---
#
# ### **Instructions 2 / 2**
#
# 1. Calculez la somme de `intro` et `intro`, puis affectez le résultat à `doubleintro`.
# 2. Affichez `doubleintro`. Vous attendiez-vous à ce résultat ?

# %%
intro = "Hello! How are you?"

# Assign sum of intro and intro to doubleintro
____

# Print out doubleintro
print(____)

# %% [markdown]
# ## **1.3 Vos apprentissages récents**

# %% [markdown]
# Vous avez appris les bases de Python, en vous concentrant sur les **variables** et les **types de données**. Voici les points clés :
#
# ### Variables
# Vous avez découvert comment créer des variables pour stocker des valeurs.
# Par exemple :
# ```python
# height = 1.79
# weight = 68.7
# ```
#
# ### Types de données
# Vous avez exploré différents types de données en Python :
#
# - **Integers (`int`)** : nombres entiers, ex. `savings = 100`
# - **Floats (`float`)** : nombres avec une partie décimale, ex. `half = 0.5`
# - **Strings (`str`)** : valeurs textuelles, ex. `intro = "Hello! How are you?"`
# - **Booleans (`bool`)** : valeurs logiques, `True` ou `False`, ex. `is_good = True`
#
# ### Vérification du type
# Vous avez utilisé la fonction `type()` pour vérifier le type d’une variable.
# Par exemple :
# ```python
# type(bmi)  # retourne float
# ```
#
# ### Opérations avec les variables
# Vous avez effectué des opérations arithmétiques avec des variables et observé que l’opérateur `+` se comporte différemment selon le type (chaînes de caractères vs nombres).
#
# ### Extrait de code de la leçon
# ```python
# # Create a variable savings
# savings = 100
#
# # Print out savings
# print(savings)
# ```
#
# Continuez à pratiquer ces notions et vous serez de plus en plus à l’aise avec les bases de Python !
#
# 🎯 **Objectif de la prochaine leçon :** découvrir comment créer et utiliser différents types de listes.

# %% [markdown]
# # **2. Les listes en Python**

# %% [markdown]
# ## **2.1 Présentation des listes**

# %% [markdown]
# Ce chapitre présente les **listes**, un moyen fondamental d’organiser et de gérer plusieurs éléments de données en Python.
# Les listes sont essentielles pour manipuler des données complexes dans vos projets.
#
# Maîtriser les listes vous permettra de **stocker et d’accéder efficacement aux informations**, ce qui est très utile pour l’analyse de données et le développement d’applications.

# %%
# @title
from IPython.display import HTML

pdf_url_02 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/02_maitriser_les_listes_python.pdf"

HTML(f"""
<a href="{pdf_url_02}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/02_maitriser_les_listes_python.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_02 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_02.png"

# Affiche l'image
Image(url=image_url_02, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_02.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Créer une liste**
#
# Une **liste** est un type de donnée composé : elle permet de regrouper plusieurs valeurs ensemble, par exemple :
#
# ```python
# a = "is"
# b = "nice"
# my_list = ["my", "list", a, b]
# ```
#
# Après avoir mesuré la taille des membres de votre famille, vous décidez de collecter des informations sur le logement dans lequel vous vivez.
# Les surfaces des différentes pièces de la maison sont stockées dans des variables séparées dans l’exercice.
#
# ---
#
# ### **Instructions**
#
# 1. Créez une liste `areas` contenant les surfaces du couloir (`hall`), de la cuisine (`kit`), du salon (`liv`), de la chambre (`bed`) et de la salle de bain (`bath`), dans cet ordre, en utilisant les variables prédéfinies.
# 2. Affichez `areas` avec la fonction `print()`.

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# Create list areas
____

# Print areas
____

# %% [markdown]
# ### **Exercice**
# **Créer des listes avec différents types**
#
# Même si ce n’est pas très courant, une liste peut contenir un mélange de différents types Python, comme des chaînes de caractères (*strings*), des nombres décimaux (*floats*) et des booléens (*booleans*).
#
# Vous allez maintenant ajouter les **noms des pièces** à votre liste afin de voir facilement à la fois le nom de la pièce et sa surface.
#
# Une partie du code vous est fournie pour vous aider à démarrer. Soyez attentif :
# `"bathroom"` est une **chaîne de caractères**, tandis que `bath` est une **variable** qui représente le nombre décimal `9.50` défini précédemment.
#
# ---
#
#
# ### **Instructions**
#
# 1. Complétez le code qui crée la liste `areas`. Construisez la liste de sorte qu’elle contienne d’abord le **nom de chaque pièce (string)** puis **sa surface**.
#   Autrement dit, ajoutez les chaînes `"hallway"`, `"kitchen"` et `"bedroom"` aux emplacements appropriés.
# 2. Affichez à nouveau `areas` ; l’affichage est-il plus informatif cette fois-ci ?

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# Adapt list areas
areas = [____, hall, ____, kit, "living room", liv, ____, bed, "bathroom", bath]

# Print areas
____

# %% [markdown]
# ### **Exercice**
# **Liste de listes**
#
# Plus tard, vous serez souvent amené à manipuler beaucoup de données. Il est donc logique de **regrouper certaines informations**.
#
# Au lieu de créer une liste contenant des chaînes de caractères et des nombres décimaux (noms et surfaces des pièces), vous pouvez créer une **liste de listes**.
#
# Rappel : `"hallway"` est une **chaîne de caractères**, tandis que `hall` est une **variable** représentant le nombre décimal `11.25` défini précédemment.
#
# ---
#
# ### **Instructions**
#
# 1. Complétez la liste de listes pour qu’elle contienne également les données de la **chambre** et de la **salle de bain**. Assurez-vous de les ajouter dans le bon ordre !
# 2. Affichez `house` ; cette façon d’organiser vos données vous semble-t-elle plus claire ?

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# House information as list of lists
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
        ____,
        ____]

# Print out house
____

# %% [markdown]
# ## **2.2 Sous-ensembles de listes (Subsetting Lists)**

# %% [markdown]
# Cette leçon vous initie au **sous-ensemble de listes** (*subsetting lists*), une compétence clé pour accéder efficacement aux données et les manipuler en Python.
#
# C’est une notion essentielle pour construire des workflows d’analyse de données plus complexes et mieux organiser vos informations.

# %%
# @title
from IPython.display import HTML

pdf_url_03 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/03_python_lists_indexing_slicing.pdf"

HTML(f"""
<a href="{pdf_url_03}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/03_python_lists_indexing_slicing.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_03 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_03.png"

# Affiche l'image
Image(url=image_url_03, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_03.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Extraire et maîtriser**
#
# Extraire des éléments (*subsetting*) d’une liste Python est très simple.
# Regardez l’exemple ci-dessous, qui crée une liste `x`, puis sélectionne `"b"`.
# Rappelez-vous : c’est le **deuxième élément**, donc son index est `1`.
# Vous pouvez aussi utiliser des **index négatifs**.
#
# ```python
# x = ["a", "b", "c", "d"]
# x[1]
# x[-3]  # même résultat !
# ```
# Rappelez-vous la liste `areas` vue précédemment, contenant à la fois des chaînes de caractères et des nombres décimaux. Sa définition est déjà présente dans le script.
# Pouvez-vous ajouter le code approprié pour effectuer du *subsetting* en Python ?
#
# ---
#
# ### **Instructions**
#
# 1. Affichez le **deuxième élément** de la liste `areas` (valeur : `11.25`).
# 2. Sélectionnez et affichez le **dernier élément** de `areas` (valeur : `9.50`). Utiliser un **index négatif** est pertinent ici.
# 3. Sélectionnez le nombre correspondant à la surface du **salon** (`20.0`) et affichez-le.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Print out second element from areas
print(areas[____])

# Print out last element from areas
print(areas[____])

# Print out the area of the living room
print(areas[____])

# %% [markdown]
# ### **Exercice**
# **Découper des listes (Slicing and dicing)**
#
# Sélectionner des valeurs individuelles dans une liste n’est qu’une partie du travail.
# Il est également possible de **découper une liste** (*slicing*), c’est-à-dire sélectionner **plusieurs éléments à la fois**.
#
# Utilisez la syntaxe suivante :
#
# ```python
# my_list[start:end]
# ```
# L’index de début (**start**) est **inclus**, tandis que l’index de fin (**end**) ne l’est pas.
# Il est également possible de ne pas préciser ces index.
# Si vous n’indiquez pas l’index de début, Python comprend que vous souhaitez commencer la découpe au **début de la liste**.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez le *slicing* pour créer une liste `downstairs` contenant les **6 premiers éléments** de `areas`.
# 2. Créez `upstairs` avec les **4 derniers éléments** de `areas`. Cette fois, simplifiez l’écriture en **n’indiquant pas l’index de fin**.
# 3. Affichez `downstairs` et `upstairs` avec `print()`.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Use slicing to create downstairs
downstairs = areas[____]

# Use slicing to create upstairs
upstairs = areas[____]

# Print out downstairs and upstairs
____
____

# %% [markdown]
# ### **Exercice**
# **Sous-ensembles de listes de listes**
#
# Une liste Python peut également contenir **d’autres listes**.
#
# Pour extraire des éléments (*subsetting*) dans des listes de listes, vous pouvez utiliser la même technique qu’avant : les **crochets**.
# Par exemple, pour une liste `house` :
#
# ```python
# house[2][0]
# ```
#
# ---
#
# ### **Instructions**
#
# 1. Faites un **subsetting** de la liste `house` pour obtenir le nombre décimal `9.5`.

# %%
house = [["hallway", 11.25],
         ["kitchen", 18.0],
         ["living room", 20.0],
         ["bedroom", 10.75],
         ["bathroom", 9.50]]

# Subset the house list
house___

# %% [markdown]
# ## **2.3 Vos apprentissages récents**
#
# Vous avez appris à faire du **subsetting de listes** en Python, une compétence essentielle pour accéder à des éléments précis et les manipuler efficacement.
#
# ### Points clés abordés
#
# - **Indexation (Indexing)**
#   Vous avez accédé aux éléments d’une liste grâce à leur index.
#   Exemple :
#   ```python
#   fam[3]
#   ```
#   → récupère le **quatrième élément**.
#
# - **Indexation négative (Negative indexing)**
#   Vous avez utilisé des index négatifs pour compter à rebours depuis la fin de la liste.
#   Exemple :
#   ```python
#   fam[-1]
#   ```
#   → récupère le **dernier élément**.
#
# ### Exemples clés
#
# - **Indexation de base (Basic Indexing)**
#   Accéder à un élément précis d’une liste à l’aide de son index.
#
#   ```python
#   x = ["a", "b", "c", "d"]
#   print(x[1])  # Output: "b"
#   print(x[-3])  # Output: "b"
#   ```
# - **Slicing**
#
#   ```python
#   x = ["a", "b", "c", "d"]
#   print(x[1:3])  # Output: ["b", "c"]
#   ```

# %% [markdown]
# ## **2.4 Manipulation des listes**

# %% [markdown]
# Ce chapitre explique comment **travailler avec les listes**, une compétence fondamentale pour organiser et manipuler efficacement des données en Python.
#
# La maîtrise de la manipulation des listes est essentielle pour construire des **tâches d’analyse de données plus complexes** et vous permettra de gérer vos données plus efficacement dans vos projets.

# %%
# @title
from IPython.display import HTML

pdf_url_04 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/04_purger_mutabilite_et_references_python.pdf"

HTML(f"""
<a href="{pdf_url_04}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/04_purger_mutabilite_et_references_python.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_04 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_04.png"

# Affiche l'image
Image(url=image_url_04, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_04.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Remplacer des éléments d’une liste**
#
# Pour remplacer des éléments dans une liste, vous pouvez faire un **subsetting**, puis **affecter une nouvelle valeur** à la sélection.
# Vous pouvez modifier un seul élément ou bien remplacer plusieurs éléments en utilisant des *slices*.
#
# Pour cet exercice (et les suivants), vous continuez à travailler avec la liste `areas`, qui contient les noms et les surfaces des différentes pièces d’une maison.
#
# ---
#
# ### **Instructions**
#
# 1. Mettez à jour la surface de la **salle de bain** pour qu’elle soit `10.50` m² au lieu de `9.50`, en utilisant un **index négatif**.
# 2. Rendez la liste `areas` plus tendance ! Remplacez `"living room"` par `"chill zone"`. Cette fois, **n’utilisez pas d’index négatif**.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Correct the bathroom area
____

# Change "living room" to "chill zone"
____

# %% [markdown]
# ### **Exercice**
# **Étendre une liste (Extend a list)**
#
# Si vous pouvez modifier des éléments dans une liste, vous voudrez aussi pouvoir en **ajouter**.
# Pour cela, vous pouvez utiliser l’opérateur `+` pour concaténer des listes.
#
# Exemple :
#
# ```python
# x = ["a", "b", "c", "d"]
# y = x + ["e", "f"]
# ```
#
# Vous venez de gagner à la loterie, génial !
# Vous décidez de construire un **poolhouse** et un **garage**. Pouvez-vous ajouter ces informations à la liste `areas` ?
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez l’opérateur `+` pour ajouter la liste `["poolhouse", 24.5]` à la fin de `areas`. Stockez la liste obtenue dans `areas_1`.
# 2. Étendez ensuite `areas_1` en ajoutant les informations sur votre garage : la chaîne `"garage"` et le nombre décimal `15.45`. Nommez la liste finale `areas_2`.

# %%
# Create the areas list and make some changes
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]

# Add poolhouse data to areas, new list is areas_1
areas_1 = ____

# Add garage data to areas_1, new list is areas_2
areas_2 = ____

# %% [markdown]
# ### **Exercice**
# **Supprimer des éléments d’une liste**
#
# Vous pouvez également **supprimer des éléments** d’une liste grâce à l’instruction `del`.
#
# Exemple :
#
# ```python
# x = ["a", "b", "c", "d"]
# del(x[1])
# ```
#
# ⚠️ Attention : dès que vous supprimez un élément d’une liste, les **index de tous les éléments suivants sont modifiés**.
#
# Malheureusement, le montant gagné à la loterie n’est finalement pas suffisant et le **poolhouse** ne verra pas le jour.
# Vous devez donc supprimer les informations correspondantes (la chaîne et le nombre décimal) de la liste `areas`.
#
# ---
#
# ### **Instructions**
#
# 1. Supprimez la chaîne `"poolhouse"` et le nombre décimal associé de la liste `areas`.
# 2. Affichez la liste `areas` mise à jour avec `print()`.

# %%
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]

# Delete the poolhouse items from the list
____

# Print the updated list
____

# %% [markdown]
# ### **Exercice**
# **Fonctionnement interne des listes**
#
# Du code est déjà fourni pour cet exercice : une liste appelée `areas` et une copie nommée `areas_copy`.
#
# Actuellement, le premier élément de la liste `areas_copy` est modifié, puis la liste `areas` est affichée.
# Si vous exécutez le code, vous verrez que, même si vous modifiez `areas_copy`, le changement affecte aussi `areas`.
#
# Cela se produit parce que **`areas` et `areas_copy` pointent vers la même liste en mémoire** (ce n’est pas une vraie copie, mais une simple référence).
#
# Si vous souhaitez éviter que les modifications apportées à `areas_copy` n’affectent `areas`, vous devez créer une **copie explicite** de la liste avec `list()` ou en utilisant `[:]`.
#
# ---
#
# ### **Instructions**
#
# 1. Modifiez la deuxième instruction, celle qui crée la variable `areas_copy`, afin que `areas_copy` soit une **copie explicite** de `areas`. Après cette modification, les changements effectués sur `areas_copy` ne devront plus affecter `areas`.

# %%
# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Change this command
areas_copy = areas

# Change areas_copy
areas_copy[0] = 5.0

# Print areas
print(areas)

# %% [markdown]
# ## **QUIZ**
#
# **Question 1**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `fall`
# ```python
# seasons = ["spring", "summer", "fall", "winter"]
# del(seasons[1])
# print(season[____])
# ```
# ---
# **Question 2** . Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `["Winter","Spring","Summer","Fall"]`
# ```python
# x = ["Winter","Spring"]
# y = ["Summer","Fall"]
# print(____)
# ```
# ---
# **Question 3**. Quelle est la sortie de ce code?
# ```python
# x = True
# y = "Python"
# print([x,y])
# ```
# 1. `['Data`, 'Python']`
# 2. `[True, 'True']`
# 3. `[True, 'Python']`
# ---
# **Question 4**. Laquelle de ces options est utilisée pour faire une **copie explicite** d’une liste?
#
# 1. The function `list()` or `[:]`
# 2. The `=` operator
# 3. The function `print()`
# ---
# **Question 5**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `['Jan', 'Feb', 'Mar', 'July']`
# ```python
# x = ["Jan","Feb","Mar","Apr"]
# x[____] = "July"
# print(x)
# ```
# ---
# **Question 6**. Quelle est la sortie de ce code?
# ```python
# x = [10, 12, 3, 7, 8]
# print(x[1:3])
# ```
# 1. `[12, 3]`
# 2. `[12, 3, 7]`
# 3. `[7]`
# ---
# **Question 7**. Laquelle de ces options correspond à une **liste valide**?
# 1. (1, 2, 3)
# 2. [1, 2, 3]
# 3. {1, 2, 3}
# ---
# **Question 8**. Quelle est la sortie de ce code?
# ```python
# x = [1,2,3]
# y = x
# y[0] = -1
# print(x)
# ```
# 1. `[1, 2, 3]`
# 2. `[-1, 2, 3]`
# 3. `[-2, 2, 3]`
# ---
# **Question 9**. Étant donné la liste suivante `x`, que renvoie `x[-1]`?
# ```python
# x = [2, 1, -4, 3, -1, 5]
# ```
# 1. `-4`
# 2. `2`
# 3. `-1`
# 4. `5`
# ---
# **Question 10**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `['Data', 'Python', 'Practice']`
# ```python
# x = [[1,2,3,4,5], ["Data", "Python", "Practice", "Exercices"]; [True, False, 0, 1]]
# print(x[____][:3])
# ```
# ---

# %% [markdown]
# ## **2.5 Vos apprentissages récents**
#
# Vous avez appris à **manipuler des listes Python**, ce qui inclut **changer, ajouter et supprimer des éléments**.
#
# ### Points clés abordés
#
# - **Modifier des éléments (Changing Elements)**
#   Vous pouvez mettre à jour un élément d’une liste en utilisant les **crochets** comme pour accéder à un élément.
#   Exemple : mettre à jour la taille de votre père dans la liste `fam` :
#   ```python
#   fam[7] = 1.86
#   ```
# - **Découper et mettre à jour (Slicing and Updating)**
#   Il est possible de modifier plusieurs éléments à la fois avec un `slice` :
#   ```python
#   fam[0:2] = ["new_name", 1.75]
#   ```
# - **Ajouter des éléments (Adding Elements)**
#   L’opérateur `+` permet de concaténer des listes.
#   Exemple : ajouter votre nom et votre taille à la liste `fam` :
#   ```python
#   fam_ext = fam + ["your_name", 1.80]
#   ```
# - **Supprimer des éléments (Deleting Elements)**
#   L’instruction `del` permet de supprimer un élément de la liste.
#   Exemple : supprimer l’élément à l’index 2 :
#   ```python
#   del fam[2]
#   ```
# - **Copier des listes (Copying Lists)**
#   Utiliser simplement `=` ne crée pas une vraie copie mais seulement une référence à la liste.
#   Pour créer une copie indépendante, utilisez `list()` ou le slicing :
#   ```python
#   y = list(x)  # ou x[:]
#   ```
#
# Ces notions sont fondamentales pour travailler efficacement avec les données en Python.

# %% [markdown]
# # **3. Les fonctions en Python**

# %% [markdown]
# ## **3.1 Introduction aux fonctions**

# %% [markdown]
# Cette leçon présente les **fonctions**, des outils essentiels pour écrire du code **efficace et réutilisable**.
# Les fonctions vous permettent de **résoudre des tâches plus rapidement** et de rendre vos programmes Python **plus puissants et organisés**.
#
# Maîtriser les fonctions rendra votre programmation Python **plus fluide et performante**.

# %%
# @title
from IPython.display import HTML

pdf_url_05 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/05_Python_Functions.pdf"

HTML(f"""
<a href="{pdf_url_05}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/05_Python_Functions.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_05 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_05.png"

# Affiche l'image
Image(url=image_url_05, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_05.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Fonctions courantes**
#
# Par défaut, Python propose de nombreuses **fonctions intégrées** (*built-in functions*) pour vous faciliter la vie.
#
# Vous connaissez déjà deux fonctions : `print()` et `type()`.
# Il existe également des fonctions comme `str()`, `int()`, `bool()` et `float()` pour **convertir entre différents types de données**.
#
# Appeler une fonction est simple.
# Par exemple, pour obtenir le type de `3.0` et stocker le résultat dans une nouvelle variable `result` :
#
# ```python
# result = type(3.0)
# ```
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez `print()` en combinaison avec `type()` pour afficher le type de `var1`.
# 2. Utilisez `len()` pour obtenir la longueur de la liste `var1`. Entourez l’appel avec `print()` pour afficher directement le résultat.
# 3. Utilisez `int()` pour convertir `var2` en entier. Stockez le résultat dans `out2`.

# %%
# Create variables var1 and var2
var1 = [1, 2, 3, 4]
var2 = True

# Print out type of var1
____

# Print out length of var1
____

# Convert var2 to an integer: out2
out2 = ____

# %% [markdown]
# ### **Exercice**
# **Aide !**
#
# Peut-être connaissez-vous déjà le nom d’une fonction Python, mais vous devez encore comprendre comment l’utiliser.
# Ironiquement, pour obtenir des informations sur une fonction, vous devez utiliser une autre fonction : `help()`.
#
# Par exemple, pour obtenir de l’aide sur la fonction `max()` :
#
# ```python
# help(max)
# ```
# Ouvrir la documentation de `pow()`.
# Pour cela, tapez `help(pow)`, puis appuyez sur Entrée.
#
# ---
#
# ### **Laquelle des affirmations suivantes est correcte ?**
#
# Réponses possibles :
#
# 1. `pow()` prend trois arguments : `base`, `exp` et `mod`. Sans `mod`, la fonction renvoie une erreur.
# 2. `pow()` prend trois arguments obligatoires : `base`, `exp` et `None`.
# 3. `pow()` nécessite les arguments `base` et `exp` ; `mod` est optionnel.
# 4. `pow()` prend deux arguments : `exp` et `mod`. L’absence de `exp` provoque une erreur.

# %%
help(pow)

# %% [markdown]
# ### **Exercice**
# **Arguments multiples**
#
# Dans l’exercice précédent, vous avez identifié des **arguments optionnels** en consultant la documentation avec `help()`.
# Vous allez maintenant appliquer cela pour modifier le comportement de la fonction `sorted()`.
#
# Consultez la documentation de `sorted()` en tapant :
# ```python
# help(sorted)
# ```
# Vous verrez que `sorted()` accepte trois arguments : `iterable`, `key` et `reverse`.
# Dans cet exercice, vous devrez uniquement spécifier `iterable` et `reverse`, pas `key`.
#
# Deux listes ont déjà été créées pour vous.
#
# Pouvez-vous les concaténer puis les trier par **ordre décroissant** ?
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez `+` pour fusionner le contenu de `first` et `second` dans une nouvelle liste appelée `full`.
# 2. Appelez `sorted()` sur `full` en définissant l’argument `reverse=True`. Enregistrez la liste triée dans `full_sorted`.
# 3. Terminez en affichant `full_sorted` avec `print()`.

# %%
# Create lists first and second
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# Paste together first and second: full
full = ____ + ____

# Sort full in descending order: full_sorted
full_sorted = ____

# Print out full_sorted
____

# %% [markdown]
# ## **3.2 Méthodes**

# %% [markdown]
# Cette leçon vous présente les **objets Python** et leurs **méthodes**, des outils essentiels pour gérer et modifier efficacement vos données.
#
# Maîtriser ces concepts vous permettra d’écrire un code **plus concis, plus clair et plus puissant** pour vos tâches d’analyse de données.

# %%
# @title
from IPython.display import HTML

pdf_url_06 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/06_Python_Methods.pdf"

HTML(f"""
<a href="{pdf_url_06}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/06_Python_Methods.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_06 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_06.png"

# Affiche l'image
Image(url=image_url_06, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_06.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Méthodes sur les chaînes (String Methods)**
#
# Les chaînes de caractères (**strings**) possèdent de nombreuses méthodes.
# Suivez attentivement les instructions pour en découvrir quelques-unes.
# Si vous voulez les explorer plus en détail, vous pouvez toujours taper `help(str)`.
#
# Une variable `place` a déjà été créée pour vos expérimentations.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez la méthode `.upper()` sur `place` et stockez le résultat dans `place_up`.
# 2. Affichez `place` et `place_up`. Les deux ont-elles changé?
# 3. Affichez le **nombre de lettres 'o'** dans la variable `place` en appelant `.count()` sur `place` et en passant `'o'` comme argument.

# %%
# string to experiment with: place
place = "poolhouse"

# Use upper() on place
place_up = ____

# Print out place and place_up
____
____

# Print out the number of o's in place
____

# %% [markdown]
# ### **Exercice**
# **Méthodes sur les listes (List Methods)**
#
# Les chaînes de caractères ne sont pas les seuls types Python à posséder des méthodes.
# Les **listes**, **floats**, **entiers** et **booléens** disposent également de nombreuses méthodes utiles.
#
# Dans cet exercice, vous allez expérimenter avec :
#
# - `.index()` : obtenir l’index du **premier élément** de la liste correspondant à l’argument.
# - `.count()` : compter le **nombre d’occurrences** d’un élément dans la liste.
#
# Vous allez travailler sur la liste `areas`, qui contient les surfaces des différentes parties d’une maison.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez la méthode `.index()` pour obtenir l’index de l’élément de `areas` égal à `20.0`.
#    Affichez cet index avec `print()`.
#
# 2. Appelez `.count()` sur `areas` pour savoir combien de fois `9.50` apparaît dans la liste.
#    Affichez simplement ce nombre avec `print()`.

# %%
# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Print out the index of the element 20.0
____

# Print out how often 9.50 appears in areas
____

# %% [markdown]
# ### **Exercice**
# **Méthodes sur les listes (2)**
#
# La plupart des méthodes de liste **modifient la liste sur laquelle elles sont appelées**.
# Exemples :
#
# - `.append()` : ajoute un élément à la liste.
# - `.remove()` : supprime le **premier élément** correspondant à l’argument.
# - `.reverse()` : inverse l’ordre des éléments de la liste.
#
# Vous allez travailler sur la liste `areas`, qui contient les surfaces des différentes parties de la maison.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez `.append()` **deux fois** pour ajouter la surface du **poolhouse** et du **garage** : `24.5` puis `15.45`. Respectez cet ordre.
# 2. Affichez la liste `areas` avec `print()`.
# 3. Utilisez la méthode `.reverse()` pour inverser l’ordre des éléments de `areas`.
# 4. Affichez à nouveau la liste `areas`.

# %%
# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Use append twice to add poolhouse and garage size
____
____

# Print out areas
____

# Reverse the orders of the elements in areas
____

# Print out areas
____

# %% [markdown]
# ## **3.3 Vos apprentissages récents**

# %% [markdown]
# **Méthodes en Python**
#
# Vous avez découvert la puissance des **méthodes**, qui sont des **fonctions associées à des objets Python** (chaînes, listes, nombres, etc.).
#
# Les méthodes permettent d’effectuer des actions spécifiques directement sur ces objets, ce qui rend votre code **plus simple, plus lisible et plus efficace**.
#
# **Points clés abordés**
#
# - Les **fonctions** sont appelées directement :
#   ```python
#   print(len(x))
#   ```
# - Les méthodes sont appelées sur un objet avec la notation par point :
#   ```python
#   "hello".capitalize()
#   ```
#   → met la première lettre en majuscule.
# - Méthodes sur les chaînes de caractères (strings)
#   Quelques exemples utiles :
#   - upper() → met tout en majuscules
#   - count('o') → compte le nombre de lettres o
#
#   Exemple :
#   ```python
#   place = "poolhouse"
#   print(place.upper())
#   print(place.count('o'))
#   ```
# - Méthodes sur les listes
#   Les listes possèdent aussi leurs propres méthodes :
#   - append() → ajoute un élément
#   - index(20.0) → trouve la position d’une valeur
#   - count(9.50) → compte les occurrences d’une valeur
#
# - Modification des listes avec des méthodes
#   Certaines méthodes modifient directement la liste :
#   - append() → ajoute à la fin
#   - reverse() → inverse l’ordre des éléments
#
# Exemple:
#   ```python
#   areas = [11.25, 18.0, 20.0, 10.75, 9.50]
#   areas.append(24.5)
#   areas.append(15.45)
#   print(areas)
#   areas.reverse()
#   print(areas)
#   ```

# %% [markdown]
# ## **3.4 Les paquets**

# %%
# @title
from IPython.display import HTML

pdf_url_07 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/07_Python_Package_Essentials.pdf"

HTML(f"""
<a href="{pdf_url_07}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/07_Python_Package_Essentials.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_07 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_07.png"

# Affiche l'image
Image(url=image_url_07, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_07.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Importer un package**
#
# Supposons que vous vouliez calculer la **circonférence** et **l’aire** d’un cercle. Voici à quoi ressemblent les formules.
#
# Plutôt que de taper la valeur du nombre π manuellement, vous pouvez utiliser le package `math` qui contient cette constante.
#
# Pour rappel, `**` est le symbole d’exponentiation.
# Par exemple, `3**4` signifie 3 puissance 4 et donne 81.
#
# ---
#
# ### **Instructions**
#
# 1. Importez le package `math`.
# 2. Utilisez `math.pi` pour calculer la circonférence du cercle et stockez-la dans `C`.
# 3. Utilisez `math.pi` pour calculer l’aire du cercle et stockez-la dans `A`.

# %%
# Import the math package
import ____

# Calculate C
C = 2 * 0.43 * ____

# Calculate A
A = ____ * 0.43 ** 2

print("Circumference: " + str(C))
print("Area: " + str(A))

# %% [markdown]
# ### **Exercice**
# **Import sélectif**
#
# Les imports généraux, comme `import math`, rendent **toutes** les fonctionnalités du package `math` disponibles.
#
# Cependant, si vous n’avez besoin que d’une partie spécifique du package, vous pouvez faire un import plus ciblé :
#
# ```python
# from math import pi
# ```
# Essayez à nouveau, mais cette fois utilisez uniquement `pi`.
#
# ---
#
# ### **Instructions**
#
# 1. Effectuez un **import sélectif** du module `math` en important uniquement `pi`.
# 2. Utilisez `pi` pour calculer la **circonférence** du cercle et stockez le résultat dans `C`.
# 3. Utilisez `pi` pour calculer l’**aire** du cercle et stockez le résultat dans `A`.

# %%
# Import pi function of math package
from math import ____

# Calculate C
C = 2 * 0.43 * ____

# Calculate A
A = ____ * 0.43 ** 2

print("Circumference: " + str(C))
print("Area: " + str(A))

# %% [markdown]
# ### **Exercice**
# **Différentes façons d’importer**
#
# Il existe plusieurs façons d’importer des **packages** et des **modules** en Python.
# Selon la méthode d’importation utilisée, vous devrez employer une syntaxe différente dans votre code Python.
#
# Supposons que vous souhaitiez utiliser la fonction `inv()`, qui se trouve dans le sous-package `linalg` du package `scipy`.
#
# Vous voulez pouvoir utiliser cette fonction de la manière suivante :
# ```python
# my_inv([[1,2], [3,4]])
# ```
# Quelle instruction d’importation devez-vous utiliser pour exécuter le code ci-dessus **sans erreur** ?
#
# ---
#
# ### **Instructions**
#
# Réponses possibles :
#
# 1. `import scipy`
# 2. `import scipy.linalg`
# 3. `from scipy.linalg import my_inv`
# 4. `from scipy.linalg import inv as my_inv`

# %%
# Votre réponse ici :

# %% [markdown]
# ## **QUIZ**
#
# **Question 1**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `3`
# ```python
# # Print the number of occurences
# # of the letter "i" in z
# z = "imagination"
# print(z____)
# ```
# ---
# **Question 2** . Quelle commande permet d’invoquer la méthode `x()` de l’objet `p` ?
# 1. `x(p)`
# 2. `p$x(p)`
# 3. `p.x()`
# 4. `x()$p`
# ---
# **Question 3**. Quelle instruction d’importation faut-il utiliser pour exécuter `cos(90)` ?
# 1. `from math import cos`
# 2. `import math and cos`
# 3. `from math import cosine`
# ---
# **Question 4**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) :
#
# `Help on built-in function len in module
#
# len(obj, /)
#
#   Return the number of items in a container`
#
# 1. `help`
# 2. `dir`
# 3. `type`
# ---
# **Question 5**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `dataanalyst`
# ```python
# "datascience".replace(____,"analyst")
# ```
# ---
# **Question 6**. Que renverra `sorted([-1, 3, -2], reverse=True)` ?
# 1. `[3, -1, -2]`
# 2. `[-1, 3, -2]`
# 3. `[-2, -1, 3]`
# ---
# **Question 7**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `array([1,2,3])`
# ```python
# import numpy as ____
# data = [1,2,3]
# np.array(data)
# ```
# 1. `np`
# 2. `data`
# 3. `np.array`
# 4. `numpy.array`
# 5. `array`
# ---
# **Question 8**. Complétez le code afin d’obtenir le résultat attendu en sortie (*output*) : `THIS IS A RANDOM SENTENCE`
# ```python
# y = "this is a random sentence"
# print(y____)
# ```
# 1. `.upcase()`
# 2. `.capitalize()`
# 3. `.upper()`
# ---
# **Question 9**. Quelle est la sortie du code suivant :
# ```python
# x = [15,10,2,84] + [1,4,8,7,9]
# x.index(x.count(x[0])
# ```
# 1. `1`
# 2. `0`
# 3. `4`
# ---
# **Question 10**. Quel sera le résultat de ce code ?
# ```python
# a = [1, 2, 3, 4]
# a.append([5, 6])
# print(len(a))
# ```
# 1. `4`
# 2. `5`
# 3. `6`
# 4. `7`
# ---

# %% [markdown]
# # **4. Numpy**

# %% [markdown]
# ## **4.1 Introduction à Numpy**

# %% [markdown]
# **Ce chapitre vous présente NumPy**
#
# Ce chapitre vous introduit à **NumPy**, un outil puissant pour l’analyse de données efficace en Python, qui vous permet d’effectuer rapidement des calculs sur des **ensembles de données entiers**.
# Maîtriser ces compétences vous aidera à gérer de **grandes collections de données** avec facilité et rapidité.

# %%
# @title
from IPython.display import HTML

pdf_url_08 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/08_NumPy_Fundamentals.pdf"

HTML(f"""
<a href="{pdf_url_08}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/08_NumPy_Fundamentals.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_08 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_08.png"

# Affiche l'image
Image(url=image_url_08, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_08.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Votre premier tableau NumPy**
#
# Vous allez maintenant plonger dans le monde du baseball. Au fil de cet exercice, vous allez vous familiariser avec les bases de **NumPy**, un puissant module utilisé en science des données.
#
# Une liste appelée `baseball` a déjà été définie dans le script Python. Elle représente la taille de certains joueurs de baseball en centimètres. Pouvez-vous ajouter du code pour créer un **tableau NumPy** à partir de cette liste ?
#
# ---
#
# ### **Instructions**
# 1. Importez le module **numpy** sous le nom `np`, afin de pouvoir utiliser `np` pour faire référence à numpy.
# 2. Utilisez `np.array()` pour créer un tableau NumPy à partir de `baseball`. Nommez ce tableau `np_baseball`.
# 3. Affichez le **type** de `np_baseball` pour vérifier que vous avez bien réussi.

# %%
# Import the numpy package as np
____

baseball = [180, 215, 210, 210, 188, 176, 209, 200]

# Create a numpy array from baseball: np_baseball
____

# Print out type of np_baseball
____

# %% [markdown]
# ### **Exercice**
# **Taille des joueurs de baseball**
#
# Vous êtes un grand fan de baseball. Vous décidez d’appeler la **MLB (Major League Baseball)** pour obtenir davantage de statistiques sur la taille des principaux joueurs. Ils vous transmettent des données concernant plus d’un millier de joueurs, stockées dans une liste Python classique appelée `height_in`. La taille est exprimée en **pouces (inches)**. Pouvez-vous créer un tableau **NumPy** à partir de ces données et convertir les unités en **mètres** ?
#
# `height_in` est déjà disponible et le module **numpy** est chargé, vous pouvez donc commencer directement.
#
# ---
#
# ### **Instructions**
# 1. Créez un tableau **NumPy** à partir de `height_in`. Nommez ce nouveau tableau `np_height_in`.
# 2. Affichez `np_height_in`.
# 3. Multipliez `np_height_in` par `0.0254` pour convertir toutes les tailles de pouces en mètres. Stockez les nouvelles valeurs dans un nouveau tableau appelé `np_height_m`.
# 4. Affichez `np_height_m` et vérifiez que le résultat est cohérent.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
height_in = [74, 74, 72, 72, 73, 69, 69, 71, 76, 71, 73, 73, 74, 74, 69, 70, 73, 75, 78, 79, 76, 74, 76, 72, 71, 75, 77, 74, 73, 74, 78, 73, 75, 73, 75, 75, 74, 69, 71, 74, 73, 73, 76, 74, 74, 70, 72, 77, 74, 70, 73, 75, 76, 76, 78, 74, 74, 76, 77, 81, 78, 75, 77, 75, 76, 74, 72, 72, 75, 73, 73, 73, 70, 70, 70, 76, 68, 71, 72, 75, 75, 75, 75, 68, 74, 78, 71, 73, 76, 74, 74, 79, 75, 73, 76, 74, 74, 73, 72, 74, 73, 74, 72, 73, 69, 72, 73, 75, 75, 73, 72, 72, 76, 74, 72, 77, 74, 77, 75, 76, 80, 74, 74, 75, 78, 73, 73, 74, 75, 76, 71, 73, 74, 76, 76, 74, 73, 74, 70, 72, 73, 73, 73, 73, 71, 74, 74, 72, 74, 71, 74, 73, 75, 75, 79, 73, 75, 76, 74, 76, 78, 74, 76, 72, 74, 76, 74, 75, 78, 75, 72, 74, 72, 74, 70, 71, 70, 75, 71, 71, 73, 72, 71, 73, 72, 75, 74, 74, 75, 73, 77, 73, 76, 75, 74, 76, 75, 73, 71, 76, 75, 72, 71, 77, 73, 74, 71, 72, 74, 75, 73, 72, 75, 75, 74, 72, 74, 71, 70, 74, 77, 77, 75, 75, 78, 75, 76, 73, 75, 75, 79, 77, 76, 71, 75, 74, 69, 71, 76, 72, 72, 70, 72, 73, 71, 72, 71, 73, 72, 73, 74, 74, 72, 75, 74, 74, 77, 75, 73, 72, 71, 74, 77, 75, 75, 75, 78, 78, 74, 76, 78, 76, 70, 72, 80, 74, 74, 71, 70, 72, 71, 74, 71, 72, 71, 74, 69, 76, 75, 75, 76, 73, 76, 73, 77, 73, 72, 72, 77, 77, 71, 74, 74, 73, 78, 75, 73, 70, 74, 72, 73, 73, 75, 75, 74, 76, 73, 74, 75, 75, 72, 73, 73, 72, 74, 78, 76, 73, 74, 75, 70, 75, 71, 72, 78, 75, 73, 73, 71, 75, 77, 72, 69, 73, 74, 72, 70, 75, 70, 72, 72, 74, 73, 74, 76, 75, 80, 72, 75, 73, 74, 74, 73, 75, 75, 71, 73, 75, 74, 74, 72, 74, 74, 74, 73, 76, 75, 72, 73, 73, 73, 72, 72, 72, 72, 71, 75, 75, 74, 73, 75, 79, 74, 76, 73, 74, 74, 72, 74, 74, 75, 78, 74, 74, 74, 77, 70, 73, 74, 73, 71, 75, 71, 72, 77, 74, 70, 77, 73, 72, 76, 71, 76, 78, 75, 73, 78, 74, 79, 75, 76, 72, 75, 75, 70, 72, 70, 74, 71, 76, 73, 76, 71, 69, 72, 72, 69, 73, 69, 73, 74, 74, 72, 71, 72, 72, 76, 76, 76, 74, 76, 75, 71, 72, 71, 73, 75, 76, 75, 71, 75, 74, 72, 73, 73, 73, 73, 76, 72, 76, 73, 73, 73, 75, 75, 77, 73, 72, 75, 70, 74, 72, 80, 71, 71, 74, 74, 73, 75, 76, 73, 77, 72, 73, 77, 76, 71, 75, 73, 74, 77, 71, 72, 73, 69, 73, 70, 74, 76, 73, 73, 75, 73, 79, 74, 73, 74, 77, 75, 74, 73, 77, 73, 77, 74, 74, 73, 77, 74, 77, 75, 77, 75, 71, 74, 70, 79, 72, 72, 70, 74, 74, 72, 73, 72, 74, 74, 76, 82, 74, 74, 70, 73, 73, 74, 77, 72, 76, 73, 73, 72, 74, 74, 71, 72, 75, 74, 74, 77, 70, 71, 73, 76, 71, 75, 74, 72, 76, 79, 76, 73, 76, 78, 75, 76, 72, 72, 73, 73, 75, 71, 76, 70, 75, 74, 75, 73, 71, 71, 72, 73, 73, 72, 69, 73, 78, 71, 73, 75, 76, 70, 74, 77, 75, 79, 72, 77, 73, 75, 75, 75, 73, 73, 76, 77, 75, 70, 71, 71, 75, 74, 69, 70, 75, 72, 75, 73, 72, 72, 72, 76, 75, 74, 69, 73, 72, 72, 75, 77, 76, 80, 77, 76, 79, 71, 75, 73, 76, 77, 73, 76, 70, 75, 73, 75, 70, 69, 71, 72, 72, 73, 70, 70, 73, 76, 75, 72, 73, 79, 71, 72, 74, 74, 74, 72, 76, 76, 72, 72, 71, 72, 72, 70, 77, 74, 72, 76, 71, 76, 71, 73, 70, 73, 73, 72, 71, 71, 71, 72, 72, 74, 74, 74, 71, 72, 75, 72, 71, 72, 72, 72, 72, 74, 74, 77, 75, 73, 75, 73, 76, 72, 77, 75, 72, 71, 71, 75, 72, 73, 73, 71, 70, 75, 71, 76, 73, 68, 71, 72, 74, 77, 72, 76, 78, 81, 72, 73, 76, 72, 72, 74, 76, 73, 76, 75, 70, 71, 74, 72, 73, 76, 76, 73, 71, 68, 71, 71, 74, 77, 69, 72, 76, 75, 76, 75, 76, 72, 74, 76, 74, 72, 75, 78, 77, 70, 72, 79, 74, 71, 68, 77, 75, 71, 72, 70, 72, 72, 73, 72, 74, 72, 72, 75, 72, 73, 74, 72, 78, 75, 72, 74, 75, 75, 76, 74, 74, 73, 74, 71, 74, 75, 76, 74, 76, 76, 73, 75, 75, 74, 68, 72, 75, 71, 70, 72, 73, 72, 75, 74, 70, 76, 71, 82, 72, 73, 74, 71, 75, 77, 72, 74, 72, 73, 78, 77, 73, 73, 73, 73, 73, 76, 75, 70, 73, 72, 73, 75, 74, 73, 73, 76, 73, 75, 70, 77, 72, 77, 74, 75, 75, 75, 75, 72, 74, 71, 76, 71, 75, 76, 83, 75, 74, 76, 72, 72, 75, 75, 72, 77, 73, 72, 70, 74, 72, 74, 72, 71, 70, 71, 76, 74, 76, 74, 74, 74, 75, 75, 71, 71, 74, 77, 71, 74, 75, 77, 76, 74, 76, 72, 71, 72, 75, 73, 68, 72, 69, 73, 73, 75, 70, 70, 74, 75, 74, 74, 73, 74, 75, 77, 73, 74, 76, 74, 75, 73, 76, 78, 75, 73, 77, 74, 72, 74, 72, 71, 73, 75, 73, 67, 67, 76, 74, 73, 70, 75, 70, 72, 77, 79, 78, 74, 75, 75, 78, 76, 75, 69, 75, 72, 75, 73, 74, 75, 75, 73]

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
# Import numpy
import numpy as np

# Create a numpy array from height_in: np_height_in
____

# Print out np_height_in
____

# Convert np_height_in to m: np_height_m
____

# Print np_height_m
____

# %% [markdown]
# ### **Exercice**
# **Effets secondaires de NumPy**
#
# **NumPy** est très pratique pour effectuer des opérations **vectorielles**. Cependant, si vous comparez son fonctionnement avec celui des **listes Python classiques**, certaines différences apparaissent.
#
# Premièrement, les **tableaux NumPy** ne peuvent pas contenir des éléments de types différents. Si vous mélangez des types, par exemple des **booléens** et des **entiers**, NumPy les convertit automatiquement vers un **type commun**.
# Les booléens comme `True` et `False` sont alors interprétés comme `1` et `0` lorsqu’ils sont combinés avec des nombres, ce qui fait que le tableau devient un tableau d’**entiers**.
#
# Deuxièmement, les opérateurs arithmétiques habituels comme `+`, `-`, `*` et `/` n’ont **pas la même signification** pour les listes Python classiques et pour les tableaux NumPy.
#
# ---
#
# ### **Question**
#
# Sélectionnez le code qui produit le résultat suivant :
# ```python
# np.array([True, 1, 2]) + np.array([3, 4, False])
# ```
# Le module **numpy** est déjà importé sous le nom `np`.
#
# Réponses possibles :
#
# 1. `np.array([True, 1, 2, 3, 4, False])`
# 2. `np.array([4, 3, 0]) + np.array([0, 2, 2])`
# 3. `np.array([1, 1, 2]) + np.array([3, 4, -1])`
# 4. `np.array([0, 1, 2, 3, 4, 5])`

# %%
# Votre réponse ici :

# %% [markdown]
# ### **Exercice**
# **Sous-sélection de tableaux NumPy**
#
# La **sous-sélection** (en utilisant la notation avec des crochets `[]` sur les listes ou les tableaux) fonctionne **exactement de la même manière** pour les listes Python et pour les tableaux NumPy.
#
# Dans cet exercice, deux listes sont déjà chargées en arrière-plan : `height_in` et `weight_lb`.
# Elles contiennent respectivement la **taille** et le **poids** des joueurs de la MLB sous forme de **listes Python classiques**.
#
# Deux tableaux **NumPy** sont également déjà préparés pour vous : `np_weight_lb` et `np_height_in`.
#
# ---
#
# ### **Instructions**
#
# 1. Sélectionnez un élément de `np_weight_lb` en affichant l’élément à **l’index 50**.
# 2. Affichez un **sous-tableau** de `np_height_in` contenant les éléments allant de **l’index 100 jusqu’à l’index 110 inclus**.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
height_in = [74, 74, 72, 72, 73, 69, 69, 71, 76, 71, 73, 73, 74, 74, 69, 70, 73, 75, 78, 79, 76, 74, 76, 72, 71, 75, 77, 74, 73, 74, 78, 73, 75, 73, 75, 75, 74, 69, 71, 74, 73, 73, 76, 74, 74, 70, 72, 77, 74, 70, 73, 75, 76, 76, 78, 74, 74, 76, 77, 81, 78, 75, 77, 75, 76, 74, 72, 72, 75, 73, 73, 73, 70, 70, 70, 76, 68, 71, 72, 75, 75, 75, 75, 68, 74, 78, 71, 73, 76, 74, 74, 79, 75, 73, 76, 74, 74, 73, 72, 74, 73, 74, 72, 73, 69, 72, 73, 75, 75, 73, 72, 72, 76, 74, 72, 77, 74, 77, 75, 76, 80, 74, 74, 75, 78, 73, 73, 74, 75, 76, 71, 73, 74, 76, 76, 74, 73, 74, 70, 72, 73, 73, 73, 73, 71, 74, 74, 72, 74, 71, 74, 73, 75, 75, 79, 73, 75, 76, 74, 76, 78, 74, 76, 72, 74, 76, 74, 75, 78, 75, 72, 74, 72, 74, 70, 71, 70, 75, 71, 71, 73, 72, 71, 73, 72, 75, 74, 74, 75, 73, 77, 73, 76, 75, 74, 76, 75, 73, 71, 76, 75, 72, 71, 77, 73, 74, 71, 72, 74, 75, 73, 72, 75, 75, 74, 72, 74, 71, 70, 74, 77, 77, 75, 75, 78, 75, 76, 73, 75, 75, 79, 77, 76, 71, 75, 74, 69, 71, 76, 72, 72, 70, 72, 73, 71, 72, 71, 73, 72, 73, 74, 74, 72, 75, 74, 74, 77, 75, 73, 72, 71, 74, 77, 75, 75, 75, 78, 78, 74, 76, 78, 76, 70, 72, 80, 74, 74, 71, 70, 72, 71, 74, 71, 72, 71, 74, 69, 76, 75, 75, 76, 73, 76, 73, 77, 73, 72, 72, 77, 77, 71, 74, 74, 73, 78, 75, 73, 70, 74, 72, 73, 73, 75, 75, 74, 76, 73, 74, 75, 75, 72, 73, 73, 72, 74, 78, 76, 73, 74, 75, 70, 75, 71, 72, 78, 75, 73, 73, 71, 75, 77, 72, 69, 73, 74, 72, 70, 75, 70, 72, 72, 74, 73, 74, 76, 75, 80, 72, 75, 73, 74, 74, 73, 75, 75, 71, 73, 75, 74, 74, 72, 74, 74, 74, 73, 76, 75, 72, 73, 73, 73, 72, 72, 72, 72, 71, 75, 75, 74, 73, 75, 79, 74, 76, 73, 74, 74, 72, 74, 74, 75, 78, 74, 74, 74, 77, 70, 73, 74, 73, 71, 75, 71, 72, 77, 74, 70, 77, 73, 72, 76, 71, 76, 78, 75, 73, 78, 74, 79, 75, 76, 72, 75, 75, 70, 72, 70, 74, 71, 76, 73, 76, 71, 69, 72, 72, 69, 73, 69, 73, 74, 74, 72, 71, 72, 72, 76, 76, 76, 74, 76, 75, 71, 72, 71, 73, 75, 76, 75, 71, 75, 74, 72, 73, 73, 73, 73, 76, 72, 76, 73, 73, 73, 75, 75, 77, 73, 72, 75, 70, 74, 72, 80, 71, 71, 74, 74, 73, 75, 76, 73, 77, 72, 73, 77, 76, 71, 75, 73, 74, 77, 71, 72, 73, 69, 73, 70, 74, 76, 73, 73, 75, 73, 79, 74, 73, 74, 77, 75, 74, 73, 77, 73, 77, 74, 74, 73, 77, 74, 77, 75, 77, 75, 71, 74, 70, 79, 72, 72, 70, 74, 74, 72, 73, 72, 74, 74, 76, 82, 74, 74, 70, 73, 73, 74, 77, 72, 76, 73, 73, 72, 74, 74, 71, 72, 75, 74, 74, 77, 70, 71, 73, 76, 71, 75, 74, 72, 76, 79, 76, 73, 76, 78, 75, 76, 72, 72, 73, 73, 75, 71, 76, 70, 75, 74, 75, 73, 71, 71, 72, 73, 73, 72, 69, 73, 78, 71, 73, 75, 76, 70, 74, 77, 75, 79, 72, 77, 73, 75, 75, 75, 73, 73, 76, 77, 75, 70, 71, 71, 75, 74, 69, 70, 75, 72, 75, 73, 72, 72, 72, 76, 75, 74, 69, 73, 72, 72, 75, 77, 76, 80, 77, 76, 79, 71, 75, 73, 76, 77, 73, 76, 70, 75, 73, 75, 70, 69, 71, 72, 72, 73, 70, 70, 73, 76, 75, 72, 73, 79, 71, 72, 74, 74, 74, 72, 76, 76, 72, 72, 71, 72, 72, 70, 77, 74, 72, 76, 71, 76, 71, 73, 70, 73, 73, 72, 71, 71, 71, 72, 72, 74, 74, 74, 71, 72, 75, 72, 71, 72, 72, 72, 72, 74, 74, 77, 75, 73, 75, 73, 76, 72, 77, 75, 72, 71, 71, 75, 72, 73, 73, 71, 70, 75, 71, 76, 73, 68, 71, 72, 74, 77, 72, 76, 78, 81, 72, 73, 76, 72, 72, 74, 76, 73, 76, 75, 70, 71, 74, 72, 73, 76, 76, 73, 71, 68, 71, 71, 74, 77, 69, 72, 76, 75, 76, 75, 76, 72, 74, 76, 74, 72, 75, 78, 77, 70, 72, 79, 74, 71, 68, 77, 75, 71, 72, 70, 72, 72, 73, 72, 74, 72, 72, 75, 72, 73, 74, 72, 78, 75, 72, 74, 75, 75, 76, 74, 74, 73, 74, 71, 74, 75, 76, 74, 76, 76, 73, 75, 75, 74, 68, 72, 75, 71, 70, 72, 73, 72, 75, 74, 70, 76, 71, 82, 72, 73, 74, 71, 75, 77, 72, 74, 72, 73, 78, 77, 73, 73, 73, 73, 73, 76, 75, 70, 73, 72, 73, 75, 74, 73, 73, 76, 73, 75, 70, 77, 72, 77, 74, 75, 75, 75, 75, 72, 74, 71, 76, 71, 75, 76, 83, 75, 74, 76, 72, 72, 75, 75, 72, 77, 73, 72, 70, 74, 72, 74, 72, 71, 70, 71, 76, 74, 76, 74, 74, 74, 75, 75, 71, 71, 74, 77, 71, 74, 75, 77, 76, 74, 76, 72, 71, 72, 75, 73, 68, 72, 69, 73, 73, 75, 70, 70, 74, 75, 74, 74, 73, 74, 75, 77, 73, 74, 76, 74, 75, 73, 76, 78, 75, 73, 77, 74, 72, 74, 72, 71, 73, 75, 73, 67, 67, 76, 74, 73, 70, 75, 70, 72, 77, 79, 78, 74, 75, 75, 78, 76, 75, 69, 75, 72, 75, 73, 74, 75, 75, 73]
weight_lb = [180, 215, 210, 210, 188, 176, 209, 200, 231, 180, 188, 180, 185, 160, 180, 185, 189, 185, 219, 230, 205, 230, 195, 180, 192, 225, 203, 195, 182, 188, 200, 180, 200, 200, 245, 240, 215, 185, 175, 199, 200, 215, 200, 205, 206, 186, 188, 220, 210, 195, 200, 200, 212, 224, 210, 205, 220, 195, 200, 260, 228, 270, 200, 210, 190, 220, 180, 205, 210, 220, 211, 200, 180, 190, 170, 230, 155, 185, 185, 200, 225, 225, 220, 160, 205, 235, 250, 210, 190, 160, 200, 205, 222, 195, 205, 220, 220, 170, 185, 195, 220, 230, 180, 220, 180, 180, 170, 210, 215, 200, 213, 180, 192, 235, 185, 235, 210, 222, 210, 230, 220, 180, 190, 200, 210, 194, 180, 190, 240, 200, 198, 200, 195, 210, 220, 190, 210, 225, 180, 185, 170, 185, 185, 180, 178, 175, 200, 204, 211, 190, 210, 190, 190, 185, 290, 175, 185, 200, 220, 170, 220, 190, 220, 205, 200, 250, 225, 215, 210, 215, 195, 200, 194, 220, 180, 180, 170, 195, 180, 170, 206, 205, 200, 225, 201, 225, 233, 180, 225, 180, 220, 180, 237, 215, 190, 235, 190, 180, 165, 195, 200, 190, 190, 185, 185, 205, 190, 205, 206, 220, 208, 170, 195, 210, 190, 211, 230, 170, 185, 185, 241, 225, 210, 175, 230, 200, 215, 198, 226, 278, 215, 230, 240, 184, 219, 170, 218, 190, 225, 220, 176, 190, 197, 204, 167, 180, 195, 220, 215, 185, 190, 205, 205, 200, 210, 215, 200, 205, 211, 190, 208, 200, 210, 232, 230, 210, 220, 210, 202, 212, 225, 170, 190, 200, 237, 220, 170, 193, 190, 150, 220, 200, 190, 185, 185, 200, 172, 220, 225, 190, 195, 219, 190, 197, 200, 195, 210, 177, 220, 235, 180, 195, 195, 190, 230, 190, 200, 190, 190, 200, 200, 184, 200, 180, 219, 187, 200, 220, 205, 190, 170, 160, 215, 175, 205, 200, 214, 200, 190, 180, 205, 220, 190, 215, 235, 191, 200, 181, 200, 210, 240, 185, 165, 190, 185, 175, 155, 210, 170, 175, 220, 210, 205, 200, 205, 195, 240, 150, 200, 215, 202, 200, 190, 205, 190, 160, 215, 185, 200, 190, 210, 185, 220, 190, 202, 205, 220, 175, 160, 190, 200, 229, 206, 220, 180, 195, 175, 188, 230, 190, 200, 190, 219, 235, 180, 180, 180, 200, 234, 185, 220, 223, 200, 210, 200, 210, 190, 177, 227, 180, 195, 199, 175, 185, 240, 210, 180, 194, 225, 180, 205, 193, 230, 230, 220, 200, 249, 190, 208, 245, 250, 160, 192, 220, 170, 197, 155, 190, 200, 220, 210, 228, 190, 160, 184, 180, 180, 200, 176, 160, 222, 211, 195, 200, 175, 206, 240, 185, 260, 185, 221, 205, 200, 170, 201, 205, 185, 205, 245, 220, 210, 220, 185, 175, 170, 180, 200, 210, 175, 220, 206, 180, 210, 195, 200, 200, 164, 180, 220, 195, 205, 170, 240, 210, 195, 200, 205, 192, 190, 170, 240, 200, 205, 175, 250, 220, 224, 210, 195, 180, 245, 175, 180, 215, 175, 180, 195, 230, 230, 205, 215, 195, 180, 205, 180, 190, 180, 190, 190, 220, 210, 255, 190, 230, 200, 205, 210, 225, 215, 220, 205, 200, 220, 197, 225, 187, 245, 185, 185, 175, 200, 180, 188, 225, 200, 210, 245, 213, 231, 165, 228, 210, 250, 191, 190, 200, 215, 254, 232, 180, 215, 220, 180, 200, 170, 195, 210, 200, 220, 165, 180, 200, 200, 170, 224, 220, 180, 198, 240, 239, 185, 210, 220, 200, 195, 220, 230, 170, 220, 230, 165, 205, 192, 210, 205, 200, 210, 185, 195, 202, 205, 195, 180, 200, 185, 240, 185, 220, 205, 205, 180, 201, 190, 208, 240, 180, 230, 195, 215, 190, 195, 215, 215, 220, 220, 230, 195, 190, 195, 209, 204, 170, 185, 205, 175, 210, 190, 180, 180, 160, 235, 200, 210, 180, 190, 197, 203, 205, 170, 200, 250, 200, 220, 200, 190, 170, 190, 220, 215, 206, 215, 185, 235, 188, 230, 195, 168, 190, 160, 200, 200, 189, 180, 190, 200, 220, 187, 240, 190, 180, 185, 210, 220, 219, 190, 193, 175, 180, 215, 210, 200, 190, 185, 220, 170, 195, 205, 195, 210, 190, 190, 180, 220, 190, 186, 185, 190, 180, 190, 170, 210, 240, 220, 180, 210, 210, 195, 160, 180, 205, 200, 185, 245, 190, 210, 200, 200, 222, 215, 240, 170, 220, 156, 190, 202, 221, 200, 190, 210, 190, 200, 165, 190, 185, 230, 208, 209, 175, 180, 200, 205, 200, 250, 210, 230, 244, 202, 240, 200, 215, 177, 210, 170, 215, 217, 198, 200, 220, 170, 200, 230, 231, 183, 192, 167, 190, 180, 180, 215, 160, 205, 223, 175, 170, 190, 240, 175, 230, 223, 196, 167, 195, 190, 250, 190, 190, 190, 170, 160, 150, 225, 220, 209, 210, 176, 260, 195, 190, 184, 180, 195, 195, 219, 225, 212, 202, 185, 200, 209, 200, 195, 228, 210, 190, 212, 190, 218, 220, 190, 235, 210, 200, 188, 210, 235, 188, 215, 216, 220, 180, 185, 200, 210, 220, 185, 231, 210, 195, 200, 205, 200, 190, 250, 185, 180, 170, 180, 208, 235, 215, 244, 220, 185, 230, 190, 200, 180, 190, 196, 180, 230, 224, 160, 178, 205, 185, 210, 180, 190, 200, 257, 190, 220, 165, 205, 200, 208, 185, 215, 170, 235, 210, 170, 180, 170, 190, 150, 230, 203, 260, 246, 186, 210, 198, 210, 215, 180, 200, 245, 200, 192, 192, 200, 192, 205, 190, 186, 170, 197, 219, 200, 220, 207, 225, 207, 212, 225, 170, 190, 210, 230, 210, 200, 238, 234, 222, 200, 190, 170, 220, 223, 210, 215, 196, 175, 175, 189, 205, 210, 180, 180, 197, 220, 228, 190, 204, 165, 216, 220, 208, 210, 215, 195, 200, 215, 229, 240, 207, 205, 208, 185, 190, 170, 208, 225, 190, 225, 185, 180, 165, 240, 220, 212, 163, 215, 175, 205, 210, 205, 208, 215, 180, 200, 230, 211, 230, 190, 220, 180, 205, 190, 180, 205, 190, 195]

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
import numpy as np

np_weight_lb = np.array(weight_lb)
np_height_in = np.array(height_in)

# Print out the weight at index 50
____

# Print out sub-array of np_height_in: index 100 up to and including index 110
____

# %% [markdown]
# ## **4.2 Tableaux NumPy 2D**

# %% [markdown]
# Cette leçon vous aide à comprendre comment travailler avec des **tableaux NumPy 2D**, une compétence essentielle pour **organiser et analyser efficacement des données** en Python.
# La maîtrise de ces tableaux vous permettra de réaliser des **manipulations de données plus avancées** dans vos projets.

# %%
# @title
from IPython.display import HTML

pdf_url_09 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/09_NumPy_Array_Fundamentals.pdf"

HTML(f"""
<a href="{pdf_url_09}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/09_NumPy_Array_Fundamentals.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_09 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_09.png"

# Affiche l'image
Image(url=image_url_09, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_09.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Votre premier tableau NumPy 2D**
#
# Avant de travailler sur les données réelles de la MLB, essayons de créer un **tableau NumPy 2D** à partir d’une petite **liste de listes**.
#
# Dans cet exercice, `baseball` est une liste de listes.
# La liste principale contient **4 éléments**, chacun étant une liste contenant **la taille et le poids** de 4 joueurs de baseball, dans cet ordre.
# `baseball` est déjà défini dans le script pour vous.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez `np.array()` pour créer un **tableau NumPy 2D** à partir de `baseball`. Nommez-le `np_baseball`.
# 2. Affichez le **type** de `np_baseball`.
# 3. Affichez l’**attribut shape** de `np_baseball` avec `np_baseball.shape`.

# %%
import numpy as np

baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Create a 2D numpy array from baseball: np_baseball
____

# Print out the type of np_baseball
____

# Print out the shape of np_baseball
____

# %% [markdown]
# ### **Exercice**
# **Données de baseball sous forme 2D**
#
# Vous vous rendez compte qu’il est plus logique de **restructurer toutes ces informations** dans un **tableau NumPy 2D**.
#
# Vous disposez d’une **liste Python de listes**.
# Dans cette liste de listes, chaque sous-liste représente **la taille et le poids d’un joueur de baseball**.
# Cette liste s’appelle `baseball`.
#
# Stocker ces données sous forme de tableau 2D permet de **débloquer les fonctionnalités supplémentaires** de NumPy.
#
# ---
#
# ### **Instructions**
#
# 1. Utilisez `np.array()` pour créer un **tableau NumPy 2D** à partir de `baseball`. Nommez-le `np_baseball`.
# 2. Affichez l’**attribut shape** de `np_baseball`.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
baseball = [[74, 180], [74, 215], [72, 210], [72, 210], [73, 188], [69, 176], [69, 209], [71, 200], [76, 231], [71, 180], [73, 188], [73, 180], [74, 185], [74, 160], [69, 180], [70, 185], [73, 189], [75, 185], [78, 219], [79, 230], [76, 205], [74, 230], [76, 195], [72, 180], [71, 192], [75, 225], [77, 203], [74, 195], [73, 182], [74, 188], [78, 200], [73, 180], [75, 200], [73, 200], [75, 245], [75, 240], [74, 215], [69, 185], [71, 175], [74, 199], [73, 200], [73, 215], [76, 200], [74, 205], [74, 206], [70, 186], [72, 188], [77, 220], [74, 210], [70, 195], [73, 200], [75, 200], [76, 212], [76, 224], [78, 210], [74, 205], [74, 220], [76, 195], [77, 200], [81, 260], [78, 228], [75, 270], [77, 200], [75, 210], [76, 190], [74, 220], [72, 180], [72, 205], [75, 210], [73, 220], [73, 211], [73, 200], [70, 180], [70, 190], [70, 170], [76, 230], [68, 155], [71, 185], [72, 185], [75, 200], [75, 225], [75, 225], [75, 220], [68, 160], [74, 205], [78, 235], [71, 250], [73, 210], [76, 190], [74, 160], [74, 200], [79, 205], [75, 222], [73, 195], [76, 205], [74, 220], [74, 220], [73, 170], [72, 185], [74, 195], [73, 220], [74, 230], [72, 180], [73, 220], [69, 180], [72, 180], [73, 170], [75, 210], [75, 215], [73, 200], [72, 213], [72, 180], [76, 192], [74, 235], [72, 185], [77, 235], [74, 210], [77, 222], [75, 210], [76, 230], [80, 220], [74, 180], [74, 190], [75, 200], [78, 210], [73, 194], [73, 180], [74, 190], [75, 240], [76, 200], [71, 198], [73, 200], [74, 195], [76, 210], [76, 220], [74, 190], [73, 210], [74, 225], [70, 180], [72, 185], [73, 170], [73, 185], [73, 185], [73, 180], [71, 178], [74, 175], [74, 200], [72, 204], [74, 211], [71, 190], [74, 210], [73, 190], [75, 190], [75, 185], [79, 290], [73, 175], [75, 185], [76, 200], [74, 220], [76, 170], [78, 220], [74, 190], [76, 220], [72, 205], [74, 200], [76, 250], [74, 225], [75, 215], [78, 210], [75, 215], [72, 195], [74, 200], [72, 194], [74, 220], [70, 180], [71, 180], [70, 170], [75, 195], [71, 180], [71, 
[73, 215], [68, 196], [72, 175], [69, 175], [73, 189], [73, 205], [75, 210], [70, 180], [70, 180], [74, 197], [75, 220], [74, 228], [74, 190], [73, 204], [74, 165], [75, 216], [77, 220], [73, 208], [74, 210], [76, 215], [74, 195], [75, 200], [73, 215], [76, 229], [78, 240], [75, 207], [73, 205], [77, 208], [74, 185], [72, 190], [74, 170], [72, 208], [71, 225], [73, 190], [75, 225], [73, 185], [67, 180], [67, 165], [76, 240], [74, 220], [73, 212], [70, 163], [75, 215], [70, 175], [72, 205], [77, 210], [79, 205], [78, 208], [74, 215], [75, 180], [75, 200], [78, 230], [76, 211], [75, 230], [69, 190], [75, 220], [72, 180], [75, 205], [73, 190], [74, 180], [75, 205], [75, 190], [73, 195]]

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
import numpy as np

# Create a 2D numpy array from baseball: np_baseball
np_baseball = ____

# Print out the shape of np_baseball
____

# %% [markdown]
# ### **Exercice**
# **Sous-sélection de tableaux NumPy 2D**
#
# Si votre **tableau NumPy 2D** a une structure régulière, c’est-à-dire que chaque ligne et chaque colonne contient un nombre fixe de valeurs, les **sous-sélections compliquées deviennent très simples**.
# Regardez l’exemple ci-dessous où les éléments `"a"` et `"c"` sont extraits d’une liste de listes :
#
# ```python
# # numpy
# import numpy as np
# np_x = np.array(x)
# np_x[:, 0]
# ```
# Les indices avant la virgule font référence aux **lignes**, tandis que ceux après la virgule font référence aux **colonnes**.
# Le symbole `:` sert à **slicer** ; dans cet exemple, il indique à Python d’inclure **toutes les lignes**.
#
# ---
#
# ### **Instructions**
#
# 1. Affichez la **50ᵉ ligne** de `np_baseball`.
# 2. Créez une nouvelle variable `np_weight_lb` contenant **toute la deuxième colonne** de `np_baseball`.
# 3. Sélectionnez la **taille** (première colonne) du **124ᵉ joueur** dans `np_baseball` et affichez-la.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
baseball = [[74, 180], [74, 215], [72, 210], [72, 210], [73, 188], [69, 176], [69, 209], [71, 200], [76, 231], [71, 180], [73, 188], [73, 180], [74, 185], [74, 160], [69, 180], [70, 185], [73, 189], [75, 185], [78, 219], [79, 230], [76, 205], [74, 230], [76, 195], [72, 180], [71, 192], [75, 225], [77, 203], [74, 195], [73, 182], [74, 188], [78, 200], [73, 180], [75, 200], [73, 200], [75, 245], [75, 240], [74, 215], [69, 185], [71, 175], [74, 199], [73, 200], [73, 215], [76, 200], [74, 205], [74, 206], [70, 186], [72, 188], [77, 220], [74, 210], [70, 195], [73, 200], [75, 200], [76, 212], [76, 224], [78, 210], [74, 205], [74, 220], [76, 195], [77, 200], [81, 260], [78, 228], [75, 270], [77, 200], [75, 210], [76, 190], [74, 220], [72, 180], [72, 205], [75, 210], [73, 220], [73, 211], [73, 200], [70, 180], [70, 190], [70, 170], [76, 230], [68, 155], [71, 185], [72, 185], [75, 200], [75, 225], [75, 225], [75, 220], [68, 160], [74, 205], [78, 235], [71, 250], [73, 210], [76, 190], [74, 160], [74, 200], [79, 205], [75, 222], [73, 195], [76, 205], [74, 220], [74, 220], [73, 170], [72, 185], [74, 195], [73, 220], [74, 230], [72, 180], [73, 220], [69, 180], [72, 180], [73, 170], [75, 210], [75, 215], [73, 200], [72, 213], [72, 180], [76, 192], [74, 235], [72, 185], [77, 235], [74, 210], [77, 222], [75, 210], [76, 230], [80, 220], [74, 180], [74, 190], [75, 200], [78, 210], [73, 194], [73, 180], [74, 190], [75, 240], [76, 200], [71, 198], [73, 200], [74, 195], [76, 210], [76, 220], [
230], [76, 203], [83, 260], [75, 246], [74, 186], [76, 210], [72, 198], [72, 210], [75, 215], [75, 180], [72, 200], [77, 245], [73, 200], [72, 192], [70, 192], [74, 200], [72, 192], [74, 205], [72, 190], [71, 186], [70, 170], [71, 197], [76, 219], [74, 200], [76, 220], [74, 207], [74, 225], [74, 207], [75, 212], [75, 225], [71, 170], [71, 190], [74, 210], [77, 230], [71, 210], [74, 200], [75, 238], [77, 234], [76, 222], [74, 200], [76, 190], [72, 170], [71, 220], [72, 223], [75, 210], [73, 215], [68, 196], [72, 175], [69, 175], [73, 189], [73, 205], [75, 210], [70, 180], [70, 180], [74, 197], [75, 220], [74, 228], [74, 190], [73, 204], [74, 165], [75, 216], [77, 220], [73, 208], [74, 210], [76, 215], [74, 195], [75, 200], [73, 215], [76, 229], [78, 240], [75, 207], [73, 205], [77, 208], [74, 185], [72, 190], [74, 170], [72, 208], [71, 225], [73, 190], [75, 225], [73, 185], [67, 180], [67, 165], [76, 240], [74, 220], [73, 212], [70, 163], [75, 215], [70, 175], [72, 205], [77, 210], [79, 205], [78, 208], [74, 215], [75, 180], [75, 200], [78, 230], [76, 211], [75, 230], [69, 190], [75, 220], [72, 180], [75, 205], [73, 190], [74, 180], [75, 205], [75, 190], [73, 195]]

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
import numpy as np

np_baseball = np.array(baseball)

# Print out the 50th row of np_baseball
____

# Select the entire second column of np_baseball: np_weight_lb
____

# Print out height of 124th player
____

# %% [markdown]
# ### **Exercice**
# **Arithmétique 2D**
#
# Les **tableaux NumPy 2D** peuvent effectuer des calculs **élément par élément**, tout comme les tableaux NumPy classiques.
#
# `np_baseball` est déjà défini pour vous ; c’est un **tableau NumPy 2D** avec **3 colonnes** représentant la **taille (en pouces)**, le **poids (en livres)** et l’**âge (en années)**.
# `baseball` est disponible sous forme de liste de listes classique.
#
# ---
#
# ### **Instructions**
#
# 1. Vous voulez **convertir les unités de taille et de poids en métrique** (mètres et kilogrammes, respectivement).
#    Comme première étape, créez un tableau NumPy avec **trois valeurs** : `0.0254`, `0.453592` et `1`. Nommez ce tableau `conversion`.
#
# 2. **Multipliez `np_baseball` par `conversion`** et affichez le résultat.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
baseball = [[74.0, 180.0, 22.99], [74.0, 215.0, 34.69], [72.0, 210.0, 30.78], [72.0, 210.0, 35.43], [73.0, 188.0, 35.71], [69.0, 176.0, 29.39], [69.0, 209.0, 30.77], [71.0, 200.0, 35.07], [76.0, 231.0, 30.19], [71.0, 180.0, 27.05], [73.0, 188.0, 23.88], [73.0, 180.0, 26.96], [74.0, 185.0, 23.29], [74.0, 160.0, 26.11], [69.0, 180.0, 27.55], [70.0, 185.0, 34.27], [73.0, 189.0, 27.99], [75.0, 185.0, 22.38], [78.0, 219.0, 22.89], [79.0, 230.0, 25.76], [76.0, 205.0, 36.33], [74.0, 230.0, 31.17], [76.0, 195.0, 32.31], [72.0, 180.0, 31.03], [71.0, 192.0, 29.26], [75.0, 225.0, 29.47], [77.0, 203.0, 32.46], [74.0, 195.0, 35.67], [73.0, 182.0, 25.89], [74.0, 188.0, 26.55], [78.0, 200.0, 24.17], [73.0, 180.0, 
 26.67], [70.0, 180.0, 34.75], [70.0, 180.0, 28.91], [74.0, 197.0, 32.73], [75.0, 220.0, 35.72], [74.0, 228.0, 42.6], [74.0, 190.0, 26.22], [73.0, 204.0, 21.85], [74.0, 165.0, 24.28], [75.0, 216.0, 22.41], [77.0, 220.0, 32.56], [73.0, 208.0, 32.74], [74.0, 210.0, 26.39], [76.0, 215.0, 28.8], [74.0, 195.0, 28.2], [75.0, 200.0, 26.52], [73.0, 215.0, 34.52], [76.0, 229.0, 34.32], [78.0, 240.0, 26.98], [75.0, 207.0, 28.86], [73.0, 205.0, 24.96], [77.0, 208.0, 25.3], [74.0, 185.0, 27.06], [72.0, 190.0, 25.44], [74.0, 170.0, 25.53], [72.0, 208.0, 34.87], [71.0, 225.0, 24.63], [73.0, 190.0, 27.99], [75.0, 225.0, 27.12], [73.0, 185.0, 31.14], [67.0, 180.0, 30.21], [67.0, 165.0, 32.11], [76.0, 240.0, 31.91], [74.0, 220.0, 34.44], [73.0, 212.0, 36.68], [70.0, 163.0, 37.66], [75.0, 215.0, 30.98], [70.0, 175.0, 27.07], [72.0, 205.0, 29.11], [77.0, 210.0, 25.82], [79.0, 205.0, 25.5], [78.0, 208.0, 29.57], [74.0, 215.0, 25.37], [75.0, 180.0, 33.99], [75.0, 200.0, 29.86], [78.0, 230.0, 31.84], [76.0, 211.0, 38.31], [75.0, 230.0, 34.48], [69.0, 190.0, 36.88], [75.0, 220.0, 32.34], [72.0, 180.0, 31.58], [75.0, 205.0, 28.89], [73.0, 190.0, 25.08], [74.0, 180.0, 25.73], [75.0, 205.0, 25.19], [75.0, 190.0, 31.01], [73.0, 195.0, 27.92]]

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
import numpy as np

np_baseball = np.array(baseball)

# Create numpy array: conversion
____

# Print out product of np_baseball and conversion
____

# %% [markdown]
# ## **4.3 NumPy : Statistiques de base**

# %% [markdown]
# Ce chapitre présente des outils qui vous aident à **analyser et comprendre de grands ensembles de données**, ce qui est essentiel pour **prendre des décisions éclairées** et obtenir des **insights** dans votre parcours en science des données.
# Vous allez apprendre à **générer des résumés significatifs** qui permettent de vérifier **la précision et la pertinence de vos données**.

# %%
# @title
from IPython.display import HTML

pdf_url_10 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/10_NumPy_Data_Exploration.pdf"

HTML(f"""
<a href="{pdf_url_10}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/presentations/10_NumPy_Data_Exploration.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_10 = "https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_10.png"

# Affiche l'image
Image(url=image_url_10, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/python_course_upjv/main/Introduction/images/infographie_10.png" width="800"/>

# %% [markdown]
# ### **Exercice**
# **Moyenne versus médiane**
#
# Vous savez maintenant comment utiliser les fonctions de **NumPy** pour mieux comprendre vos données.
#
# Les données de baseball sont disponibles sous la forme d’un **tableau NumPy 2D** avec **3 colonnes** (*taille, poids, âge*) et **1015 lignes**.
# Le nom de ce tableau NumPy est **`np_baseball`**.
#
# Après avoir restructuré les données, vous remarquez cependant que certaines valeurs de **taille** sont anormalement élevées. Suivez les instructions et découvrez **quelle statistique descriptive est la plus adaptée lorsque l’on est confronté à des valeurs aberrantes (outliers)**.
#
# `np_baseball` est disponible.
#
# ---
#
# ### **Instructions**
#
# 1. Créez le tableau NumPy **`np_height_in`** qui correspond à **la première colonne de `np_baseball`**.
# 2. Affichez la **moyenne** (*mean*) de `np_height_in`.
# 3. Affichez la **médiane** (*median*) de `np_height_in`.
# 4. Pourquoi l'écart entre la **moyenne** et la **médiane** est si important?

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
import numpy as np

np_baseball = np.array([
 [7.400e+04, 1.800e+02, 2.299e+01],
 [7.400e+01, 2.150e+02, 3.469e+01],
 [7.200e+01, 2.100e+02, 3.078e+01],
 [7.200e+01, 2.100e+02, 3.543e+01],
 [7.300e+01, 1.880e+02, 3.571e+01],
 [6.900e+01, 1.760e+02, 2.939e+01],
 [6.900e+01, 2.090e+02, 3.077e+01],
 [7.100e+01, 2.000e+02, 3.507e+01],
 [7.600e+01, 2.310e+02, 3.019e+01],
 [7.100e+01, 1.800e+02, 2.705e+01],
 [7.300e+01, 1.880e+02, 2.388e+01],
 [7.300e+01, 1.800e+02, 2.696e+01],
 [7.400e+01, 1.850e+02, 2.329e+01],
 [7.400e+01, 1.600e+02, 2.611e+01],
 [6.900e+01, 1.800e+02, 2.755e+01],
 [7.000e+01, 1.850e+02, 3.427e+01],
 [7.300e+01, 1.890e+02, 2.799e+01],
 [7.500e+01, 1.850e+02, 2.238e+01],
 [7.800e+01, 2.190e+02, 2.289e+01],
 [7.900e+01, 2.300e+02, 2.576e+01],
 [7.600e+01, 2.050e+02, 3.633e+01],
 [7.400e+01, 2.300e+02, 3.117e+01],
 [7.600e+01, 1.950e+02, 3.231e+01],
 [7.200e+01, 1.800e+02, 3.103e+01],
 [7.100e+01, 1.920e+02, 2.926e+01],
 [7.500e+01, 2.250e+02, 2.947e+01],
 [7.700e+01, 2.030e+02, 3.246e+01],
 [7.400e+01, 1.950e+02, 3.567e+01],
 [7.300e+01, 1.820e+02, 2.589e+01],
 [7.400e+01, 1.880e+02, 2.655e+01],
 [7.800e+01, 2.000e+02, 2.417e+01],
 [7.300e+01, 1.800e+02, 2.669e+01],
 [7.500e+01, 2.000e+02, 2.513e+01],
 [7.300e+01, 2.000e+02, 2.790e+01],
 [7.500e+01, 2.450e+02, 3.017e+01],
 [7.500e+01, 2.400e+02, 3.136e+01],
 [7.400e+01, 2.150e+02, 3.099e+01],
 [6.900e+01, 1.850e+02, 3.224e+01],
 [7.100e+01, 1.750e+02, 2.761e+01],
 [7.400e+01, 1.990e+02, 2.820e+01],
 [7.300e+01, 2.000e+02, 2.885e+01],
 [7.300e+01, 2.150e+02, 2.421e+01],
 [7.000e+01, 1.630e+02, 3.766e+01],
 [7.500e+01, 2.150e+02, 3.098e+01],
 [7.000e+01, 1.750e+02, 2.707e+01],
 [7.200e+01, 2.050e+02, 2.911e+01],
 [7.700e+01, 2.100e+02, 2.582e+01],
 [7.900e+01, 2.050e+02, 2.550e+01],
 [7.800e+01, 2.080e+02, 2.957e+01],
 [7.400e+04, 2.150e+02, 2.537e+01],
 [7.500e+01, 1.800e+02, 3.399e+01],
 [7.500e+01, 2.000e+02, 2.986e+01],
 [7.800e+01, 2.300e+02, 3.184e+01],
 [7.600e+01, 2.110e+02, 3.831e+01],
 [7.500e+01, 2.300e+02, 3.448e+01],
 [6.900e+01, 1.900e+02, 3.688e+01],
 [7.500e+01, 2.200e+02, 3.234e+01],
 [7.200e+01, 1.800e+02, 3.158e+01],
 [7.500e+01, 2.050e+02, 2.889e+01],
 [7.300e+01, 1.900e+02, 2.508e+01],
 [7.400e+01, 1.800e+02, 2.573e+01],
 [7.500e+01, 2.050e+02, 2.519e+01],
 [7.500e+01, 1.900e+02, 3.101e+01],
 [7.300e+01, 1.950e+02, 2.792e+01]
])

# %% [markdown]
# **VOUS POUVEZ CODER APRES L'EXECUTION DE LA CELLULE PRECEDENTE**

# %%
import numpy as np

# Create np_height_in from np_baseball
____

# Print out the mean of np_height_in
____

# Print out the median of np_height_in
____

# Explication
____

# %% [markdown]
# ### **Exercice**
# **Explorer les données de baseball**
#
# Comme la **moyenne** et la **médiane** sont très éloignées l’une de l’autre, vous décidez de vous plaindre auprès de la **MLB**. Ils trouvent l’erreur et vous envoient les **données corrigées**.
#
# Elles sont à nouveau disponibles sous forme d’un **tableau NumPy 2D `np_baseball`**, avec **trois colonnes**.
#
# Le script Python dans l’éditeur contient déjà le code permettant d’afficher des messages informatifs avec différentes **statistiques descriptives**, et **NumPy est déjà importé sous le nom `np`**.
#
# Pouvez-vous terminer le travail ?
#
# `np_baseball` est disponible.
#
# ---
#
# ### **Instructions**
#
# 1. Le code pour afficher la **taille moyenne** est déjà inclus. Complétez le code pour afficher la **taille médiane**.
# 2. Utilisez **`np.std()`** sur **la première colonne de `np_baseball`** afin de calculer **l’écart-type (stddev)**.
# 3. Les joueurs grands ont-ils tendance à être plus lourds ? Utilisez **`np.corrcoef()`** pour stocker **la corrélation entre la première et la deuxième colonne de `np_baseball`** dans la variable **`corr`**.
# 4. Pouvez vous expliquer la corrélation entre le **poids** et la **taille**.

# %% [markdown]
# **CELLULE A EXECUTER EN PREMIER**

# %%
# @title
import numpy as np

np_baseball = np.array([
 [7.400e+01, 1.800e+02, 2.299e+01],
 [7.400e+01, 2.150e+02, 3.469e+01],
 [7.200e+01, 2.100e+02, 3.078e+01],
 [7.200e+01, 2.100e+02, 3.543e+01],
 [7.300e+01, 1.880e+02, 3.571e+01],
 [6.900e+01, 1.760e+02, 2.939e+01],
 [6.900e+01, 2.090e+02, 3.077e+01],
 [7.100e+01, 2.000e+02, 3.507e+01],
 [7.600e+01, 2.310e+02, 3.019e+01],
 [7.100e+01, 1.800e+02, 2.705e+01],
 [7.300e+01, 1.880e+02, 2.388e+01],
 [7.300e+01, 1.800e+02, 2.696e+01],
